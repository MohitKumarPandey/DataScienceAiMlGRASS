# %%
import pandas as pd 
df=pd.Series(["hello",10,20,30]) # if data is in 1d form and in list form then Series is used
print(df)
d={"name":"mohit","age":19,"roll":196}
Df=pd.Series(data=d,index=['name','age','roll'])
print(Df)

# help -->||
# help(pd.Series)
# suggestions 
# pd.Series??
# Out:
# 0    hello
# 1       10
# 2       20
# 3       30
# dtype: object
# name    mohit
# age        19
# roll      196
# dtype: object

# %%
# data frame
import pandas as pd

d = {
    "name":["kunal","dheeraj","anjali","praveen","yash","danish"],
    "roll-no":[12,13,14,15,16,17]
}
df = pd.DataFrame(data=d)
print(df)
# Out:
#       name  roll-no
# 0    kunal       12
# 1  dheeraj       13
# 2   anjali       14
# 3  praveen       15
# 4     yash       16
# 5   danish       17

# %%
# import files from 
# github
# file me space ho to %20 lgana pdta h 
url="https://raw.githubusercontent.com/05mohitkumar146-lgtm/DataScienceGrass/main/file2%20-%20Sheet1.csv"
df=pd.read_csv(url)
df

# read excel 
url="https://raw.githubusercontent.com/05mohitkumar146-lgtm/DataScienceGrass/main/file1.xlsx"
DfExcel=pd.read_excel(url)
DfExcel

# read json 
url=url="https://raw.githubusercontent.com/05mohitkumar146-lgtm/DataScienceGrass/main/file1.json"
DfJson=pd.read_json(url)
DfJson
# drive 
# normal file in system
# Out:
#        name  roll no
# 0   dheeraj      123
# 1     kunal     1234
# 2  abhishek    12345
# 3   praveen    12356
# 4    anjali  1234567
