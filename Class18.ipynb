# %% [markdown]
# import numpy as n
# import pandas as pd
# url = "https://raw.githubusercontent.com/rajendra0968jangid/Ds-Arya/main/file2.json"
# df = pd.read_json(url)
# df

# %%
import numpy as np
import pandas as pd 
url = "https://raw.githubusercontent.com/rajendra0968jangid/Ds-Arya/main/file2.json"
df = pd.read_json(url)
df

# %%
# handling missing values 
# need to handle missing value
df.isnull()
df.loc[4,'marks']=np.nan
df.loc[3,'roll no']=None
# df.fillna('NULL')
df.isnull()
# column count missing value 
# df.isnull().sum()
# df

# %%
# null --> generic missing values, jiski value optional ho 
# NaN --> generally numeric columns me use hota h

# %%
import numpy as np
import pandas as pd 
url = "https://raw.githubusercontent.com/rajendra0968jangid/Ds-Arya/main/file2.json"
df = pd.read_json(url)
df
df.fillna(30)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~\miniconda3\Lib\urllib\request.py:1319, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1318 try:
# -> 1319     h.request(req.get_method(), req.selector, req.data, headers,
#    1320               encode_chunked=req.has_header('Transfer-encoding'))
#    1321 except OSError as err: # timeout error
#
# File ~\miniconda3\Lib\http\client.py:1358, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1357 """Send a complete request to the server."""
# -> 1358 self._send_request(method, url, body, headers, encode_chunked)
#
# File ~\miniconda3\Lib\http\client.py:1404, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1403     body = _encode(body, 'body')
# -> 1404 self.endheaders(body, encode_chunked=encode_chunked)
#
# ...

# %%
# aggregation 
df['marks'].mean()
df['marks'].max()
df['marks'].min()
df['marks'].median()
df['marks'].sum()
df['marks'].mode()
df['marks'].agg(['mean','median','sum','min','max'])

# %%
import matplotlib.pyplot as plt 
score=[10,20,30,40]
over=[1,2,3,4]
plt.plot(score,over)
plt.show()
plt.xlabel("score")
plt.ylabel("over")
plt.title("Cricket")
# Out:
# Text(0.5, 1.0, 'Cricket')
