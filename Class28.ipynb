# %%
# project 
# take data from mySql data base 
# model dump and integrate with backend 
# deploy the project

# %%
# project using mysql and joblib and slr

# %%
#!pip install mysql-connector-python

# %%
import numpy as np 
import pandas as pd 
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
data ={
    'name':['mohit','dheeraj','yash','kunal'],
    'avg_income':[1000,200,300,400], 
    'house_age':[10.2,2.5,3.0,4.0],
    'num_rooms':[3,4,5,1], 
    'price':[10000,7000,15000,11000]
}
df=pd.DataFrame(data)
df
# Out:
#       name  avg_income  house_age  num_rooms  price
# 0    mohit        1000       10.2          3  10000
# 1  dheeraj         200        2.5          4   7000
# 2     yash         300        3.0          5  15000
# 3    kunal         400        4.0          1  11000

# %%
# handle missing values 
# df.drop('name',axis=1,inplace=True)
# feature scaling 
scaler=StandardScaler()
df[['avg_income','house_age','num_rooms']]=scaler.fit_transform(df[['avg_income','house_age','num_rooms']])
df
# Out:
#       name  avg_income  house_age  num_rooms  price
# 0    mohit    1.686761   1.705444  -0.169031  10000
# 1  dheeraj   -0.883541  -0.784019   0.507093   7000
# 2     yash   -0.562254  -0.622366   1.183216  15000
# 3    kunal   -0.240966  -0.299059  -1.521278  11000

# %%
# split data 
X=df[['avg_income','house_age','num_rooms']]
y=df['price']

x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=2)

# %%
# model train 
model=LinearRegression()
model.fit(x_train,y_train)
# prediction 
new_data=pd.DataFrame({
    "avg_income":[200],
    "house_age":[8],
    "num_rooms":[4]
})
# feature_scaling
new_data[['avg_income','house_age','num_rooms']]=scaler.fit_transform(new_data[['avg_income','house_age','num_rooms']])
predict_data=model.predict(new_data)
print(predict_data[0])
# Out:
# 8496.575851006844

# %%
# model dump 
#!pip install joblib
import joblib
joblib.dump(model,"house_predict.joblib")
# Out:
# ['house_predict.joblib']

# %%
# mysql connection 
# mysql connector
# !pip install pymysql cryptography
import pymysql
conn = pymysql.connect(host="13.220.156.88",user="mluser",database="ml_db",password="mlpass123")
print(conn)
query = "select avg_income,house_age,num_rooms,price,name from houses"
df = pd.read_sql(query,conn)
print(df)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~\miniconda3\Lib\site-packages\pymysql\connections.py:682, in Connection.connect(self, sock)
#     681 try:
# --> 682     sock = socket.create_connection(
#     683         (self.host, self.port), self.connect_timeout, **kwargs
#     684     )
#     685     break
#
# File ~\miniconda3\Lib\socket.py:864, in create_connection(address, timeout, source_address, all_errors)
#     863 if not all_errors:
# --> 864     raise exceptions[0]
#     865 raise ExceptionGroup("create_connection failed", exceptions)
#
# File ~\miniconda3\Lib\socket.py:849, in create_connection(address, timeout, source_address, all_errors)
#     848     sock.bind(source_address)
# --> 849 sock.connect(sa)
#     850 # Break explicitly a reference cycle
#
# TimeoutError: timed out
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[9], line 5
#       1 # mysql connection
#       2 # mysql connector
#       3 # !pip install pymysql cryptography
#       4 import pymysql
# ----> 5 conn = pymysql.connect(host="13.220.156.88",user="mluser",database="ml_db",password="mlpass123")
#       6 print(conn)
#       7 query = "select avg_income,house_age,num_rooms,price,name from houses"
#
# File ~\miniconda3\Lib\site-packages\pymysql\connections.py:372, in Connection.__init__(self, user, password, host, database, unix_socket, port, charset, collation, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_key_password, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     370     self._sock = None
#     371 else:
# --> 372     self.connect()
#
# File ~\miniconda3\Lib\site-packages\pymysql\connections.py:744, in Connection.connect(self, sock)
#     742     if DEBUG:
#     743         print(exc.traceback)
# --> 744     raise exc
#     746 # If e is neither DatabaseError or IOError, It's a bug.
#     747 # But raising AssertionError hides original error.
#     748 # So just reraise it.
#     749 raise
#
# OperationalError: (2003, "Can't connect to MySQL server on '13.220.156.88' (timed out)")

# %%
# from sqlalchemy import create_engine

# engine = create_engine(
#     "mysql+mysqlconnector://mluser:mlpass123@13.220.156.88/ml_db"
# )

# try:
#     with engine.connect() as conn:
#         print("Connection Successful")
# except Exception as e:
#     print(e)

# %%
# from sqlalchemy import create_engine
# import pandas as pd

# engine = create_engine("mysql+mysqlconnector://mluser:mlpass123@13.220.156.88/ml_db")

# query = "SELECT avg_income, house_age, num_rooms, price FROM houses"

# df2 = pd.read_sql(query, engine)

# print(df2.head())
